# %%
import os
# !pip install python-box pyyaml ensure
# Out:
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    ------------------------ --------------- 0.8/1.3 MB 1.2 MB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.3 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.3 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [python-box]
#    ---------------------------------------- 2/2 [ensure]
#
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pwd
# Out:
# 'D:\\DataAnalytics\\nlp\\Text-Summarizer'

# %%
os.chdir("D:\\DataAnalytics\\nlp\\Text-Summarizer")

# %%
# %pwd
# Out:
# 'D:\\DataAnalytics\\nlp\\Text-Summarizer'

# %%
from dataclasses import dataclass
from pathlib import Path

# %%
@dataclass(frozen = True)
class dataIngestionConfig:
    root_dir: Path
    source_url: str
    local_data_file: Path
    unzip_dir: Path

# %%
os.chdir("D:\\DataAnalytics\\nlp\\Text-Summarizer\\src\\textsummarizer")

# %%
# %pwd
# Out:
# 'D:\\DataAnalytics\\nlp\\Text-Summarizer\\src\\textsummarizer'

# %%
from src.textsummarizer.utils import *
from src.textsummarizer.constants import *

# %%
class ConfigurationManager:
    def __init__(self, config_file_path = CONFIG_FILE_PATH, param_file_path = PARAM_FILE_PATH):
        self.config = read_yaml(config_file_path)
        self.config = read_yaml(param_file_path)
        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 def get_data_ingestion_config(self) -> DataIngestionConfig:
#       2     config = self.config.data_ingestion
#
# NameError: name 'DataIngestionConfig' is not defined
